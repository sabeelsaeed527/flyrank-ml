# %% [markdown]
# <a href="https://colab.research.google.com/github/sabeelsaeed527/flyrank-ml/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install duckdb lightgbm scikit-learn matplotlib pandas numpy

# %%
# ==============================================================================
# GENERAL AI FLUENCY · IMPACT PROJECT (WEEK 6 - CODE: FL)
# Portfolio Sustainability & Habit System
# ==============================================================================

impact_project_doc = """
# Portfolio Sustainability & Habit System (Week 6 Impact Project)

## 1. "How to Add the Next Case" Playbook (3-Beat Shape)
To keep my portfolio fresh and systematically updated, every future case study will follow this repeatable three-beat structure:

* *Beat 1 — Problem Statement (The Challenge & Decision):*
  Write 2-3 sentences explaining the exact business or technical challenge, why it mattered, who the target decision-maker was, and the core metric we aimed to move.

* *Beat 2 — What I Did (Methodology & Stack):*
  Summarize the end-to-end technical execution: data sources extracted (e.g., Hugging Face / DuckDB queries), features engineered, modeling techniques (e.g., LightGBM classification), leakage-prevention strategies, and AI prompt engineering used.

* *Beat 3 — What Came of It (Impact & Deliverable):*
  Document the quantitative results (e.g., F1-score lift over baseline), state the directional business impact, link to the deployed visual research paper, and list 3 key actionable takeaways.

---

## 2. Named Next Work
* *Project Name:* Automated Search Query Intent Classifier & CTR Anomaly Engine
* *Scope & Objective:* Building an unsupervised/supervised hybrid ML pipeline on search warehouse data to group search queries by user intent (Informational, Transactional, Navigational) and detect underperforming CTR anomalies for instant content optimization.

---

## 3. Evidence of Concrete Reminder Set
* *Reminder Mechanism:* Recurring Google Calendar / Phone Task notification created.
* *Schedule & Recurrence:* Set for the 1st of every month at 10:00 AM.
* *Event Title:* "Portfolio Maintenance: Build, Document & Ship Next AI Case Study"
* *Status:* Active & recurring monthly to enforce portfolio maintenance habits.

---

## 4. Build Context Preservation (Claude / AI Project)
* *Preserved System Prompt & Kit:* Saved custom Claude Project instructions containing identity kit, preferred stack configuration (DuckDB, LightGBM, scikit-learn, GitHub Pages template), and analytical tone guidelines.
* *Low-Friction Updates:* Reusing this preserved build context ensures future case study creation requires only a short conversation and data update—not a ground-up rebuild.
"""

# Write to a Markdown file in your Colab environment
with open("impact_project_week6.md", "w") as f:
    f.write(impact_project_doc.strip())

print("✅ Week 6 Impact Project Document Generated Successfully!")
print("=======================================================")
print(impact_project_doc.strip())
# Out:
# ✅ Week 6 Impact Project Document Generated Successfully!
# ...
# # Portfolio Sustainability & Habit System (Week 6 Impact Project)
#
# ## 1. "How to Add the Next Case" Playbook (3-Beat Shape)
# To keep my portfolio fresh and systematically updated, every future case study will follow this repeatable three-beat structure:
#
# * *Beat 1 — Problem Statement (The Challenge & Decision):*
#   Write 2-3 sentences explaining the exact business or technical challenge, why it mattered, who the target decision-maker was, and the core metric we aimed to move.
#
# * *Beat 2 — What I Did (Methodology & Stack):*
#   Summarize the end-to-end technical execution: data sources extracted (e.g., Hugging Face / DuckDB queries), features engineered, modeling techniques (e.g., LightGBM classification), leakage-prevention strategies, and AI prompt engineering used.
#
# * *Beat 3 — What Came of It (Impact & Deliverable):*
# ...
